# %%
import os
os.chdir('./清理后的数据/')
filelist = os.listdir()

csv_list = [x for x in filelist if 'csv' in x]
csv_list
# Out:
# ['交通运输、仓储和邮政业清洗完成的数据.csv',
#  '住宿和餐饮业清洗完成的数据.csv',
#  '信息传输、软件和信息技术服务业清洗完成的数据.csv',
#  '农、林、牧、渔业清洗完成的数据.csv',
#  '制造业清洗完成的数据.csv',
#  '卫生和社会工作清洗完成的数据.csv',
#  '居民服务、修理和其他服务业清洗完成的数据.csv',
#  '建筑业清洗完成的数据.csv',
#  '房地产业清洗完成的数据.csv',
#  '批发和零售业清洗完成的数据.csv',
#  '教育清洗完成的数据.csv',
#  '文化、体育和娱乐业清洗完成的数据.csv',
#  '水利、环境和公共设施管理业清洗完成的数据.csv',
#  '电力、热力、燃气及水生产和供应业清洗完成的数据.csv',
#  '科学研究和技术服务业清洗完成的数据.csv',
#  '租赁和商务服务业清洗完成的数据.csv',
#  '综合清洗完成的数据.csv',
#  '采矿业清洗完成的数据.csv',
#  '金融业清洗完成的数据.csv']

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE   # SMOTE采样
from collections import Counter
from sklearn.ensemble import AdaBoostClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
from sklearn.ensemble import RandomForestClassifier  # 随机森林
import lightgbm as lgb # lightgbm
from sklearn.ensemble import GradientBoostingClassifier # GBDT
from sklearn.linear_model import LogisticRegression # 逻辑回归
from sklearn.tree import DecisionTreeClassifier 
from sklearn.svm import SVC
# import xgboost
# from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score



os.getcwd()  # 'C:\\Users\\dell\\zhaoxuan'
os.listdir()  # 列出所有文件

filelist = os.listdir()

csv_list = [x for x in filelist if '数据.csv' in x]
# print(csv_list)
# print(csv_list[0])

for i in range(len(csv_list)):
    print(csv_list[i][:-11])
    col_list = pd.read_csv('../指标/300次训练.csv',encoding='gbk',header=None)
    new_col = list(col_list[col_list[0]==(csv_list[i][:-11])][1])  # 注意文件要求
    new_col.append('TICKER_SYMBOL')
    new_col.append('FLAG')
    print(new_col)
    data_rate = pd.read_csv(csv_list[i])
    data_rate = data_rate[new_col]
    data_X = data_rate[~data_rate['FLAG'].isnull()]
    data_Y = data_rate[data_rate['FLAG'].isnull()]
    data_X['FLAG'] = data_X['FLAG'].apply(lambda x :int(x))
    X_1 = data_X[data_X['FLAG']==1]
    X_0 = data_X[data_X['FLAG']==0].sample(X_1.shape[0]*3)
    X_0 = X_0.append(X_1)
    print(data_rate.shape)
    print(X_1.shape)
    if data_rate.shape[1] <=3:
        continue
#     if data_rate.shape[0] >=20:
# #         X_tr, X_te, Y_tr, Y_te = train_test_split(X_0.iloc[:,:-2],X_0.iloc[:,-1],test_size=0.3)   # 拆分训练集、测试集,12,134
#         X_tr , Y_tr = X_0.iloc[:,:-2],X_0.iloc[:,-1]
#         sos = SMOTE(random_state=0)  # SMOTE采样
#         X_sos, y_sos = sos.fit_resample(X_tr, Y_tr)
#     else:
    X_sos, y_sos  = X_0.iloc[:,:-2],X_0.iloc[:,-1]


    clf_adaboost = AdaBoostClassifier()
    clf_adaboost.fit(X_sos, y_sos)
    pre_q2 = clf_adaboost.predict(data_Y.iloc[:,:-2])
    data_Y['FLAG'] = pre_q2
    data_Y.iloc[:,-2:].to_csv('{}问题3.csv'.format(i))
# Out:
# 交通运输、仓储和邮政业
# ['T_LIAB', 'CAPITAL_RESER', 'T_NCL', 'PAID_IN_CAPITAL', 'SURPLUS_RESER', 'T_CL', 'DEFER_REVENUE', 'LT_BORR', 'RETAINED_EARNINGS', 'DEFER_TAX_LIAB', 'T_EQUITY_ATTR_P', 'LT_PAYABLE', 'T_LIAB_EQUITY', 'NCL_WITHIN_1Y', 'PREPAYMENT', 'MINORITY_INT', 'T_SH_EQUITY', 'AR', 'NOTES_RECEIV', 'OTH_CA', 'OTH_PAYABLE', 'C_PAID_OTH_FINAN_A', 'OTH_COMPRE_INCOME', 'OTH_RECEIV', 'T_CA', 'LT_EQUITY_INVEST', 'DIV_PAYABLE', 'INVENTORIES', 'FIXED_ASSETS', 'N_CF_FR_INVEST_A', 'TICKER_SYMBOL', 'FLAG']
# (541, 32)
# (3, 32)
# 住宿和餐饮业
# ['TICKER_SYMBOL', 'FLAG']
# (56, 2)
# (0, 2)
# 信息传输、软件和信息技术服务业
# ['REFUND_OF_TAX', 'C_FR_BORR', 'AVAIL_FOR_SALE_FA', 'T_NCL', 'OTH_CA', 'RETAINED_EARNINGS', 'PAID_IN_CAPITAL', 'DILUTED_EPS', 'BASIC_EPS', 'LT_AMOR_EXP', 'PREPAYMENT', 'MINORITY_INT', 'OTH_PAYABLE', 'SURPLUS_RESER', 'ST_BORR', 'N_CF_FR_INVEST_A', 'FINAN_EXP', 'PAYROLL_PAYABLE', 'N_CE_END_BAL', 'CAPITAL_RESER', 'INTAN_ASSETS', 'N_CE_BEG_BAL', 'DEFER_REVENUE', 'FOREX_EFFECTS', 'LT_EQUITY_INVEST', 'CASH_C_EQUIV', 'C_FR_OTH_OPERATE_A', 'C_PAID_INVEST', 'ADVANCE_RECEIPTS', 'OPERATE_PROFIT', 'TICKER_SYMBOL', 'FLAG']
# (1576, 32)
# (15, 32)
# 农、林、牧、渔业
# ['MINORITY_INT', 'DEFER_REVENUE', 'T_NCL', 'SURPLUS_RESER', 'T_LIAB', 'CAPITAL_RESER', 'T_CL', 'LT_BORR', 'PAID_IN_CAPITAL', 'T_EQUITY_ATTR_P', 'RETAINED_EARNINGS', 'PREPAYMENT', 'T_SH_EQUITY', 'AR', 'OTH_RECEIV', 'NCL_WITHIN_1Y', 'INVENTORIES', 'OTH_PAYABLE', 'T_LIAB_EQUITY', 'T_CA', 'AVAIL_FOR_SALE_FA', 'OTH_CA', 'CIP', 'C_PAID_OTH_FINAN_A', 'FIXED_ASSETS', 'LT_EQUITY_INVEST', 'T_COGS', 'INT_PAYABLE', 'N_CF_FR_INVEST_A', 'C_FR_BORR', 'TICKER_SYMBOL', 'FLAG']
# (228, 32)
# (7, 32)
# 制造业
# ['ASSETS_IMPAIR_LOSS', 'C_PAID_OTH_FINAN_A', 'C_INF_FR_INVEST_A', 'DILUTED_EPS', 'REFUND_OF_TAX', 'C_PAID_INVEST', 'GAIN_INVEST', 'OTH_PAYABLE', 'OTH_CA', 'C_PAID_FOR_TAXES', 'GOING_CONCERN_NI', 'C_FR_OTH_OPERATE_A', 'NOPERATE_INCOME', 'INVEST_INCOME', 'C_FR_OTH_INVEST_A', 'DISP_FIX_ASSETS_OTH', 'TAXES_PAYABLE', 'BASIC_EPS', 'N_CF_OPERATE_A', 'NOTES_RECEIV', 'PAID_IN_CAPITAL', 'C_PAID_TO_FOR_EMPL', 'N_CF_FR_INVEST_A', 'AVAIL_FOR_SALE_FA', 'N_CHANGE_IN_CASH', 'NOTES_PAYABLE', 'INT_PAYABLE', 'C_OUTF_FR_INVEST_A', 'OTH_NCA', 'RETAINED_EARNINGS', 'TICKER_SYMBOL', 'FLAG']
# (12287, 32)
# (80, 32)
# 卫生和社会工作
# ['TICKER_SYMBOL', 'FLAG']
# (65, 2)
# (0, 2)
# 居民服务、修理和其他服务业
# ['TICKER_SYMBOL', 'FLAG']
# (5, 2)
# (0, 2)
# 建筑业
# ['T_LIAB', 'T_NCL', 'OTH_PAYABLE', 'NCL_WITHIN_1Y', 'T_CL', 'LT_BORR', 'DEFER_REVENUE', 'PAID_IN_CAPITAL', 'RETAINED_EARNINGS', 'SURPLUS_RESER', 'CAPITAL_RESER', 'DEFER_TAX_LIAB', 'OTH_CL', 'NOTES_RECEIV', 'INT_PAYABLE', 'TAXES_PAYABLE', 'PREPAYMENT', 'AR', 'MINORITY_INT', 'T_EQUITY_ATTR_P', 'INVENTORIES', 'OTH_RECEIV', 'PAYROLL_PAYABLE', 'OTH_CA', 'T_CA', 'T_SH_EQUITY', 'AVAIL_FOR_SALE_FA', 'ADVANCE_RECEIPTS', 'T_LIAB_EQUITY', 'T_COGS', 'TICKER_SYMBOL', 'FLAG']
# (460, 32)
# (5, 32)
# 房地产业
# ['ASSETS_IMPAIR_LOSS', 'BASIC_EPS', 'DILUTED_EPS', 'OTH_COMPR_INCOME', 'OPERATE_PROFIT', 'COMPR_INC_ATTR_P', 'INVEST_INCOME', 'N_INCOME_ATTR_P', 'T_COMPR_INCOME', 'T_PROFIT', 'A_J_INVEST_INCOME', 'T_REVENUE', 'FINAN_EXP', 'REVENUE', 'NOPERATE_EXP', 'SELL_EXP', 'ADMIN_EXP', 'C_OUTF_FR_FINAN_A', 'LT_EQUITY_INVEST', 'C_PAID_TO_FOR_EMPL', 'COGS', 'PUR_FIX_ASSETS_OTH', 'N_INCOME', 'BIZ_TAX_SURCHG', 'C_INF_FR_FINAN_A', 'NOPERATE_INCOME', 'N_C_IN_CASH_PS', 'INCOME_TAX', 'COMPR_INC_ATTR_M_S', 'AR_TURNOVER', 'TICKER_SYMBOL', 'FLAG']
# (586, 32)
# (8, 32)
# 批发和零售业
# ['DILUTED_EPS', 'BASIC_EPS', 'C_OUTF_FR_INVEST_A', 'C_FR_OTH_OPERATE_A', 'NOPERATE_EXP', 'N_CF_FR_FINAN_A', 'A_J_INVEST_INCOME', 'DISP_FIX_ASSETS_OTH', 'PUR_FIX_ASSETS_OTH', 'ADMIN_EXP', 'REVENUE', 'N_CE_END_BAL', 'C_OUTF_FR_FINAN_A', 'C_PAID_TO_FOR_EMPL', 'T_REVENUE', 'N_CE_BEG_BAL', 'C_INF_FR_FINAN_A', 'FINAN_EXP', 'T_PROFIT', 'C_PAID_FOR_DEBTS', 'AR_TURNOVER', 'OPERATE_PROFIT', 'ASSETS_IMPAIR_LOSS', 'C_INF_FR_INVEST_A', 'OTH_COMPR_INCOME', 'NOPERATE_INCOME', 'RETAINED_EARNINGS', 'COMPR_INC_ATTR_P', 'N_CHANGE_IN_CASH', 'OTH_CA', 'TICKER_SYMBOL', 'FLAG']
# (906, 32)
# (13, 32)
# 教育
# ['T_COGS', 'MINORITY_INT', 'T_CL', 'T_NCL', 'T_LIAB', 'PAID_IN_CAPITAL', 'CAPITAL_RESER', 'SURPLUS_RESER', 'RETAINED_EARNINGS', 'T_EQUITY_ATTR_P', 'T_SH_EQUITY', 'INT_PAYABLE', 'T_LIAB_EQUITY', 'OTH_COMPRE_INCOME', 'C_PAID_OTH_FINAN_A', 'N_CF_FR_INVEST_A', 'C_FR_BORR', 'N_CF_OPERATE_A', 'C_PAID_INVEST', 'C_INF_FR_INVEST_A', 'OTH_PAYABLE', 'TAXES_PAYABLE', 'PAYROLL_PAYABLE', 'AR', 'PREPAYMENT', 'OTH_RECEIV', 'INVENTORIES', 'OTH_CA', 'T_CA', 'AVAIL_FOR_SALE_FA', 'TICKER_SYMBOL', 'FLAG']
# (48, 32)
# (1, 32)
# 文化、体育和娱乐业
# ['INT_PAYABLE', 'OTH_PAYABLE', 'T_CL', 'DEFER_REVENUE', 'T_NCL', 'T_LIAB', 'PAID_IN_CAPITAL', 'CAPITAL_RESER', 'SURPLUS_RESER', 'RETAINED_EARNINGS', 'T_EQUITY_ATTR_P', 'T_COGS', 'T_SH_EQUITY', 'N_CF_FR_INVEST_A', 'MINORITY_INT', 'PAYROLL_PAYABLE', 'PREPAYMENT', 'OTH_RECEIV', 'T_LIAB_EQUITY', 'OTH_COMPRE_INCOME', 'C_PAID_OTH_FINAN_A', 'NOTES_RECEIV', 'AR', 'INVENTORIES', 'OTH_CA', 'INTAN_ASSETS', 'C_PAID_INVEST', 'C_PAID_G_S', 'T_CA', 'LT_EQUITY_INVEST', 'TICKER_SYMBOL', 'FLAG']
# (315, 32)
# (2, 32)
# 水利、环境和公共设施管理业
# ['TAXES_PAYABLE', 'OTH_PAYABLE', 'NCL_WITHIN_1Y', 'T_CL', 'LT_BORR', 'DEFER_REVENUE', 'T_NCL', 'T_LIAB', 'PAID_IN_CAPITAL', 'CAPITAL_RESER', 'SURPLUS_RESER', 'RETAINED_EARNINGS', 'T_EQUITY_ATTR_P', 'INT_PAYABLE', 'NOTES_RECEIV', 'AR', 'ADVANCE_RECEIPTS', 'MINORITY_INT', 'PREPAYMENT', 'OTH_RECEIV', 'T_SH_EQUITY', 'C_FR_BORR', 'INVENTORIES', 'LT_EQUITY_INVEST', 'OTH_CA', 'C_FR_OTH_FINAN_A', 'T_COGS', 'PAYROLL_PAYABLE', 'T_LIAB_EQUITY', 'C_PAID_OTH_FINAN_A', 'TICKER_SYMBOL', 'FLAG']
# (307, 32)
# (2, 32)
# 电力、热力、燃气及水生产和供应业
# ['C_FR_OTH_INVEST_A', 'C_OUTF_OPERATE_A', 'C_PAID_FOR_DEBTS', 'C_PAID_DIV_PROF_INT', 'C_PAID_FOR_TAXES', 'N_CE_BEG_BAL', 'C_OUTF_FR_INVEST_A', 'C_FR_SALE_G_S', 'N_CHANGE_IN_CASH', 'DISP_FIX_ASSETS_OTH', 'GAIN_INVEST', 'INCOME_TAX', 'NOPERATE_INCOME', 'C_FR_OTH_OPERATE_A', 'N_CF_FR_FINAN_A', 'C_INF_FR_OPERATE_A', 'C_INF_FR_FINAN_A', 'N_CE_END_BAL', 'COMPR_INC_ATTR_M_S', 'REFUND_OF_TAX', 'NOPERATE_EXP', 'MINORITY_GAIN', 'DIV_PROF_SUBS_MINO_S', 'C_PAID_TO_FOR_EMPL', 'PUR_FIX_ASSETS_OTH', 'C_OUTF_FR_FINAN_A', 'PROC_SELL_INVEST', 'BIZ_TAX_SURCHG', 'GOING_CONCERN_NI', 'C_PAID_FOR_OTH_OP_A', 'TICKER_SYMBOL', 'FLAG']
# (597, 32)
# (4, 32)
# 科学研究和技术服务业
# ['OTH_PAYABLE', 'T_CL', 'DEFER_REVENUE', 'T_NCL', 'T_LIAB', 'PAID_IN_CAPITAL', 'TAXES_PAYABLE', 'CAPITAL_RESER', 'SURPLUS_RESER', 'PAYROLL_PAYABLE', 'ADVANCE_RECEIPTS', 'NOTES_RECEIV', 'CIP', 'RETAINED_EARNINGS', 'AR', 'PREPAYMENT', 'T_COGS', 'T_EQUITY_ATTR_P', 'MINORITY_INT', 'OTH_RECEIV', 'T_SH_EQUITY', 'N_CF_FR_INVEST_A', 'INVENTORIES', 'T_LIAB_EQUITY', 'OTH_CA', 'C_PAID_OTH_FINAN_A', 'AVAIL_FOR_SALE_FA', 'LT_EQUITY_INVEST', 'T_CA', 'C_FR_BORR', 'TICKER_SYMBOL', 'FLAG']
# (264, 32)
# (3, 32)
# 租赁和商务服务业
# ['TICKER_SYMBOL', 'FLAG']
# (293, 2)
# (0, 2)
# 综合
# ['AR_TURNOVER', 'INCOME_TAX', 'NOPERATE_EXP', 'BIZ_TAX_SURCHG', 'N_INCOME', 'COGS', 'SELL_EXP', 'FINAN_EXP', 'INVEST_INCOME', 'N_INCOME_ATTR_P', 'T_COMPR_INCOME', 'OTH_COMPR_INCOME', 'COMPR_INC_ATTR_P', 'ASSETS_IMPAIR_LOSS', 'OPERATE_PROFIT', 'BASIC_EPS', 'T_PROFIT', 'T_REVENUE', 'REVENUE', 'A_J_INVEST_INCOME', 'DILUTED_EPS', 'ADMIN_EXP', 'C_OUTF_FR_FINAN_A', 'C_PAID_TO_FOR_EMPL', 'C_INF_FR_FINAN_A', 'PUR_FIX_ASSETS_OTH', 'N_CE_END_BAL', 'N_CE_BEG_BAL', 'N_CF_FR_FINAN_A', 'DISP_FIX_ASSETS_OTH', 'TICKER_SYMBOL', 'FLAG']
# (90, 32)
# (1, 32)
# 采矿业
# ['SURPLUS_RESER', 'RETAINED_EARNINGS', 'SPECIAL_RESER', 'OTH_CA', 'T_NCL', 'PAID_IN_CAPITAL', 'T_EQUITY_ATTR_P', 'NOTES_RECEIV', 'DEFER_REVENUE', 'T_LIAB', 'T_SH_EQUITY', 'CAPITAL_RESER', 'LT_BORR', 'DEFER_TAX_LIAB', 'AR', 'NCL_WITHIN_1Y', 'T_CL', 'PREPAYMENT', 'MINORITY_INT', 'INVENTORIES', 'T_LIAB_EQUITY', 'T_CA', 'AVAIL_FOR_SALE_FA', 'C_PAID_OTH_FINAN_A', 'OTH_RECEIV', 'LT_EQUITY_INVEST', 'T_COGS', 'OTH_PAYABLE', 'OTH_COMPRE_INCOME', 'FIXED_ASSETS', 'TICKER_SYMBOL', 'FLAG']
# (412, 32)
# (3, 32)
# 金融业
# ['SURPLUS_RESER', 'FIXED_ASSETS', 'INVEST_REAL_ESTATE', 'LT_EQUITY_INVEST', 'MINORITY_INT', 'RETAINED_EARNINGS', 'T_COGS', 'N_CF_FR_INVEST_A', 'CAPITAL_RESER', 'C_PAID_INVEST', 'T_EQUITY_ATTR_P', 'N_CF_OPERATE_A', 'OTH_COMPRE_INCOME', 'ORDIN_RISK_RESER', 'INT_RECEIV', 'T_SH_EQUITY', 'NOPERATE_EXP', 'T_LIAB_EQUITY', 'INT_PAYABLE', 'LOAN_FR_OTH_BANK_FI', 'C_FR_CAP_CONTR', 'PAID_IN_CAPITAL', 'TRADING_FA', 'FOREX_EFFECTS', 'BOND_PAYABLE', 'NOPERATE_INCOME', 'DEFER_TAX_LIAB', 'GAIN_INVEST', 'INTAN_ASSETS', 'C_INF_FR_INVEST_A', 'TICKER_SYMBOL', 'FLAG']
# (573, 32)
# (11, 32)
